# %%
import pandas as pd
import pickle
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', None)
pd.set_option('max_r', None)

# %%
#load the overall results of cross_validation and hyper parameter tuning
df = pickle.load(open('CV_RESULTS.pickle', 'rb'))

# %%
#look at model perplexity and accuracy
print("Least perplexed")
print(df.sort_values('Validation Perplex', ascending=True).head(5))
# Out:
# Least perplexed
#                            Train Accuracy  Train Perplex  Validation Accuracy  Validation Perplex                                           Params
# RandomForestClassifier-16        0.956522       3.274026             0.825137            2.592445  {'min_samples_split': 5, 'min_samples_leaf': 6}
# RandomForestClassifier-9         0.934066       3.583337             0.773842            2.670051  {'min_samples_split': 5, 'min_samples_leaf': 6}
# RandomForestClassifier-2         0.956522       3.480623             0.814208            2.672461  {'min_samples_split': 5, 'min_samples_leaf': 6}
# RandomForestClassifier-4         0.956044       3.662169             0.771117            2.674342  {'min_samples_split': 5, 'min_samples_leaf': 6}
# RandomForestClassifier-24        0.945055       3.615671             0.811989            2.686461  {'min_samples_split': 5, 'min_samples_leaf': 6}

# %%
print("Most accurate")
print(df.sort_values('Validation Accuracy', ascending=False).head(5))
# Out:
# Most accurate
#                        Train Accuracy  Train Perplex  Validation Accuracy  Validation Perplex                                                         Params
# LogisticRegression-25        0.824176       6.417302             0.858311            6.958293  {'C': 0.9237666583949777, 'penalty': 'l2', 'solver': 'lbfgs'}
# SVC-25                       0.956044       8.789773             0.850136            6.317369                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# LogisticRegression-18        0.891304      25.887611             0.841530           42.581095  {'C': 0.9237666583949777, 'penalty': 'l2', 'solver': 'lbfgs'}
# SVC-1                        0.956522       6.287732             0.838798            5.261623                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-12                       0.902174       3.726694             0.838798            3.313540                      {'C': 3.829710375376188, 'kernel': 'rbf'}

# %%
print("Most perplexed")
print(df.sort_values('Validation Perplex', ascending=False).head(5))
# Out:
# Most perplexed
#                        Train Accuracy  Train Perplex  Validation Accuracy  Validation Perplex                                                         Params
# LogisticRegression-22        0.978261      96.205510             0.806011           49.459312  {'C': 0.9237666583949777, 'penalty': 'l2', 'solver': 'lbfgs'}
# GaussianNB-24                0.857143      95.422516             0.762943           43.790269                                                             {}
# LogisticRegression-18        0.891304      25.887611             0.841530           42.581095  {'C': 0.9237666583949777, 'penalty': 'l2', 'solver': 'lbfgs'}
# GaussianNB-16                0.750000     126.355306             0.715847           38.491018                                                             {}
# LogisticRegression-6         0.923913      43.512047             0.786885           35.397852  {'C': 0.9237666583949777, 'penalty': 'l2', 'solver': 'lbfgs'}

# %%
print("Least accurate")
print(df.sort_values('Validation Accuracy', ascending=True).head(5))
# Out:
# Least accurate
#                Train Accuracy  Train Perplex  Validation Accuracy  Validation Perplex Params
# GaussianNB-16        0.750000     126.355306             0.715847           38.491018     {}
# GaussianNB-23        0.815217      51.192284             0.724044           17.089036     {}
# GaussianNB-10        0.813187      37.228509             0.738420           22.579873     {}
# GaussianNB-2         0.891304      47.008593             0.743169           24.559742     {}
# GaussianNB-9         0.813187      56.521278             0.746594           19.000741     {}

# %%
#the whole summary
df
# Out:
#                            Train Accuracy  Train Perplex  Validation Accuracy  Validation Perplex                                                         Params
# RandomForestClassifier-1         0.978261       3.567921             0.808743            2.847775                {'min_samples_split': 5, 'min_samples_leaf': 6}
# RandomForestClassifier-2         0.956522       3.480623             0.814208            2.672461                {'min_samples_split': 5, 'min_samples_leaf': 6}
# RandomForestClassifier-3         0.913043       3.962938             0.795082            2.857846                {'min_samples_split': 5, 'min_samples_leaf': 6}
# RandomForestClassifier-4         0.956044       3.662169             0.771117            2.674342                {'min_samples_split': 5, 'min_samples_leaf': 6}
# RandomForestClassifier-5         0.978022       4.444270             0.795640            3.109435                {'min_samples_split': 5, 'min_samples_leaf': 6}
# RandomForestClassifier-6         0.956522       3.981533             0.767760            2.802219                {'min_samples_split': 5, 'min_samples_leaf': 6}
# RandomForestClassifier-7         0.956522       3.763812             0.814208            2.767552                {'min_samples_split': 5, 'min_samples_leaf': 6}
# RandomForestClassifier-8         0.934783       3.688925             0.816940            2.836002                {'min_samples_split': 5, 'min_samples_leaf': 6}
# RandomForestClassifier-9         0.934066       3.583337             0.773842            2.670051                {'min_samples_split': 5, 'min_samples_leaf': 6}
# RandomForestClassifier-10        0.934066       3.879507             0.779292            2.813141                {'min_samples_split': 5, 'min_samples_leaf': 6}
# RandomForestClassifier
# GaussianNB-13                    0.923913      10.921777             0.775956            8.246623                                                             {}
# GaussianNB-14                    0.857143      62.059395             0.801090           30.036588                                                             {}
# GaussianNB-15                    0.835165      63.471566             0.765668           21.819250                                                             {}
# GaussianNB-16                    0.750000     126.355306             0.715847           38.491018                                                             {}
# GaussianNB-17                    0.826087      12.506064             0.756831            7.486236                                                             {}
# GaussianNB-18                    0.815217      12.731803             0.781421           13.626940                                                             {}
# GaussianNB-19                    0.868132      83.170933             0.765668           26.543192                                                             {}
# GaussianNB-20                    0.890110      32.941885             0.790191           12.599554                                                             {}
# GaussianNB-21                    0.880435      24.555075             0.775956           13.923315                                                             {}
# GaussianNB-22                    0.782609      15.510861             0.765027           13.138845                                                             {}
# GaussianNB-23                    0.815217      51.192284             0.724044           17.089036                                                             {}
# GaussianNB-24                    0.857143      95.422516             0.762943           43.790269                                                             {}
# GaussianNB-25                    0.857143      20.271293             0.768392            7.681726                                                             {}
# SVC-1                            0.956522       6.287732             0.838798            5.261623                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-2                            0.934783       7.466722             0.827869            5.631767                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-3                            0.967391       8.153048             0.811475            5.208282                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-4                            0.978022       9.359342             0.828338            6.918938                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-5                            0.956044      11.240638             0.806540            6.572050                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-6                            0.989130      25.903478             0.836066           12.389050                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-7                            0.956522       5.540821             0.822404            4.565397                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-8                            0.945652       6.916115             0.800546            4.809399                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-9                            0.967033      10.145941             0.822888            5.925683                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-10                           0.945055       8.926372             0.801090            5.755382                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-11                           0.978261      20.265616             0.825137           11.780448                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-12                           0.902174       3.726694             0.838798            3.313540                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-13                           0.956522      11.249338             0.808743            6.316671                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-14                           0.978022      12.234749             0.820163            6.978500                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-15                           0.956044       8.974837             0.806540            5.654478                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-16                           0.956522      10.571937             0.808743            6.345148                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-17                           0.945652      10.094742             0.838798            6.551465                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-18                           0.978261       9.025165             0.838798            5.792585                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-19                           0.978022       8.568785             0.825613            6.569640                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-20                           0.934066      11.171498             0.825613            9.699804                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-21                           0.956522       6.262282             0.830601            5.376547                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-22                           0.967391      18.213633             0.838798           11.431350                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-23                           0.934783       5.858297             0.825137            4.858972                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-24                           0.978022      14.661100             0.795640            7.352240                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-25                           0.956044       8.789773             0.850136            6.317369                      {'C': 3.829710375376188, 'kernel': 'rbf'}

# %%
#you can also investigate how the params of each model were chosen
##example performance of logistic regression hyperparameter tuning
#you can reuse this code to read the other models: just chose a different pickle file
#the parameters were tuning using crossfold validation also
lrp = pd.read_pickle('LogisticRegression-parameter_tuning.pickle')
lrp[['mean_test_score', 'std_test_score', 'rank_test_score', 'params']].sort_values('rank_test_score', ascending=True)
# Out:
#     mean_test_score  std_test_score  rank_test_score                                                              params
# 0          0.845043        0.053962                1       {'C': 0.9237666583949777, 'penalty': 'l2', 'solver': 'lbfgs'}
# 9          0.844935        0.053494                2       {'C': 0.5636157747519341, 'penalty': 'l2', 'solver': 'lbfgs'}
# 3          0.844826        0.053994                3       {'C': 0.7987417046727168, 'penalty': 'l2', 'solver': 'lbfgs'}
# 6          0.844826        0.053994                3       {'C': 0.6904364516090982, 'penalty': 'l2', 'solver': 'lbfgs'}
# 14         0.844826        0.054125                3        {'C': 1.087442906903663, 'penalty': 'l2', 'solver': 'lbfgs'}
# 8          0.844717        0.053922                6   {'C': 1.4097309261553663, 'penalty': 'l2', 'solver': 'newton-cg'}
# 11         0.844717        0.053922                6       {'C': 1.6870199211367845, 'penalty': 'l2', 'solver': 'lbfgs'}
# 19         0.844717        0.053966                8       {'C': 0.6516663720064764, 'penalty': 'l2', 'solver': 'lbfgs'}
# 1          0.844713        0.053085                9  {'C': 0.45802478587592566, 'penalty': 'l2', 'solver': 'newton-cg'}
# 16         0.844611        0.053844               10   {'C': 3.0803561250163276, 'penalty': 'l2', 'solver': 'newton-cg'}
# 15         0.844611        0.053844               10        {'C': 2.516454479648476, 'penalty': 'l2', 'solver': 'lbfgs'}
# 2          0.844611        0.053844               10   {'C': 3.2361382009613666, 'penalty': 'l2', 'solver': 'newton-cg'}
# 7          0.844611        0.053844               10        {'C': 3.766539408293475, 'penalty': 'l2', 'solver': 'lbfgs'}
# 5          0.844611        0.053844               10        {'C': 3.646472822013713, 'penalty': 'l2', 'solver': 'lbfgs'}
# 4          0.844611        0.053844               10   {'C': 2.8625422022310496, 'penalty': 'l2', 'solver': 'newton-cg'}
# 18         0.844611        0.053844               10        {'C': 2.943741567749782, 'penalty': 'l2', 'solver': 'lbfgs'}
# 10         0.844611        0.053844               10       {'C': 3.4386621906659007, 'penalty': 'l2', 'solver': 'lbfgs'}
# 12         0.844609        0.053894               18   {'C': 1.9228562259374238, 'penalty': 'l2', 'solver': 'newton-cg'}
# 17         0.844500        0.053777               19         {'C': 2.07455476266405, 'penalty': 'l2', 'solver': 'lbfgs'}
# 13         0.844300        0.050822               20   {'C': 0.0697221820081837, 'penalty': 'l2', 'solver': 'newton-cg'}

# %%
svcp = pd.read_pickle('SVC-parameter_tuning.pickle')
svcp[['mean_test_score', 'std_test_score', 'rank_test_score', 'params']].sort_values('rank_test_score', ascending=True)
# Out:
#     mean_test_score  std_test_score  rank_test_score                                          params
# 18         0.857007        0.049202                1       {'C': 3.829710375376188, 'kernel': 'rbf'}
# 15         0.853700        0.047096                2      {'C': 1.3400783293272838, 'kernel': 'rbf'}
# 17         0.850771        0.047424                3      {'C': 0.9301317895411385, 'kernel': 'rbf'}
# 13         0.848360        0.049411                4      {'C': 0.7249131567350804, 'kernel': 'rbf'}
# 16         0.843899        0.047774                5      {'C': 3.168085572717698, 'kernel': 'poly'}
# 10         0.843896        0.048121                6      {'C': 2.881014573887268, 'kernel': 'poly'}
# 8          0.843795        0.048466                7      {'C': 3.265651819034257, 'kernel': 'poly'}
# 2          0.842490        0.046598                8     {'C': 1.9830105146414194, 'kernel': 'poly'}
# 9          0.841816        0.051802                9     {'C': 0.31778272119557993, 'kernel': 'rbf'}
# 4          0.841302        0.046506               10     {'C': 1.8268856482973406, 'kernel': 'poly'}
# 5          0.837374        0.047142               11     {'C': 1.2321450997129393, 'kernel': 'poly'}
# 1          0.834952        0.046465               12     {'C': 0.9309605895633108, 'kernel': 'poly'}
# 0          0.832341        0.045744               13      {'C': 0.671288376491697, 'kernel': 'poly'}
# 14         0.831121        0.057064               14     {'C': 0.12427203526525021, 'kernel': 'rbf'}
# 6          0.829490        0.047577               15      {'C': 0.601400503676921, 'kernel': 'poly'}
# 19         0.759790        0.063424               16  {'C': 0.7618672939914006, 'kernel': 'sigmoid'}
# 3          0.750850        0.066529               17  {'C': 1.3250049879679842, 'kernel': 'sigmoid'}
# 7          0.747464        0.063828               18   {'C': 2.437570865518892, 'kernel': 'sigmoid'}
# 11         0.747116        0.065316               19  {'C': 2.2376590404741474, 'kernel': 'sigmoid'}
# 12         0.746461        0.065448               20  {'C': 2.9987446307812085, 'kernel': 'sigmoid'}

# %%
rfp = pd.read_pickle('RandomForestClassifier-parameter_tuning.pickle')
rfp[['mean_test_score', 'std_test_score', 'rank_test_score', 'params']].sort_values('rank_test_score', ascending=True)
# Out:
#     mean_test_score  std_test_score  rank_test_score                                           params
# 15         0.857147        0.049833                1  {'min_samples_split': 6, 'min_samples_leaf': 2}
# 7          0.855824        0.050561                2  {'min_samples_split': 3, 'min_samples_leaf': 1}
# 3          0.855705        0.049772                3  {'min_samples_split': 4, 'min_samples_leaf': 4}
# 14         0.855283        0.047849                4  {'min_samples_split': 2, 'min_samples_leaf': 5}
# 6          0.854722        0.050212                5  {'min_samples_split': 4, 'min_samples_leaf': 2}
# 11         0.853609        0.048279                6  {'min_samples_split': 5, 'min_samples_leaf': 1}
# 0          0.853324        0.048904                7  {'min_samples_split': 2, 'min_samples_leaf': 3}
# 9          0.853312        0.047664                8  {'min_samples_split': 6, 'min_samples_leaf': 4}
# 10         0.853300        0.048532                9  {'min_samples_split': 2, 'min_samples_leaf': 1}
# 16         0.853092        0.048324               10  {'min_samples_split': 5, 'min_samples_leaf': 6}
# 19         0.853087        0.049932               11  {'min_samples_split': 5, 'min_samples_leaf': 5}
# 4          0.853085        0.051353               12  {'min_samples_split': 6, 'min_samples_leaf': 6}
# 8          0.852862        0.050315               13  {'min_samples_split': 4, 'min_samples_leaf': 3}
# 12         0.852862        0.049443               13  {'min_samples_split': 3, 'min_samples_leaf': 2}
# 5          0.852539        0.050434               15  {'min_samples_split': 2, 'min_samples_leaf': 2}
# 13         0.852524        0.049932               16  {'min_samples_split': 4, 'min_samples_leaf': 6}
# 1          0.851896        0.049153               17  {'min_samples_split': 4, 'min_samples_leaf': 1}
# 17         0.851763        0.050640               18  {'min_samples_split': 3, 'min_samples_leaf': 3}
# 18         0.850807        0.047320               19  {'min_samples_split': 4, 'min_samples_leaf': 5}
# 2          0.850804        0.050472               20  {'min_samples_split': 5, 'min_samples_leaf': 2}
