# %%
import pandas as pd
import pickle
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', None)
pd.set_option('max_r', None)

# %%
#load the overall results of cross_validation and hyper parameter tuning
df = pickle.load(open('CV_RESULTS.pickle', 'rb'))

# %%
#look at model perplexity and accuracy
print("Least perplexed")
print(df.sort_values('Validation Perplex', ascending=True).head(5))
# Out:
# Least perplexed
#                        Train Accuracy  Train Perplex  Validation Accuracy  Validation Perplex                                                         Params
# SVC-22                       0.967391       1.128971             0.838798            1.437783                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-17                       0.945652       1.185260             0.838798            1.443543                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-18                       0.978261       1.176890             0.838798            1.454002                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-1                        0.956522       1.259574             0.838798            1.455602                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# LogisticRegression-25        0.824176       1.501729             0.858311            1.459962  {'C': 0.9237666583949777, 'penalty': 'l2', 'solver': 'lbfgs'}

# %%
print("Most accurate")
print(df.sort_values('Validation Accuracy', ascending=False).head(5))
# Out:
# Most accurate
#                            Train Accuracy  Train Perplex  Validation Accuracy  Validation Perplex                                                         Params
# LogisticRegression-25            0.824176       1.501729             0.858311            1.459962  {'C': 0.9237666583949777, 'penalty': 'l2', 'solver': 'lbfgs'}
# SVC-25                           0.956044       1.197122             0.850136            1.468701                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# RandomForestClassifier-19        1.000000       1.267766             0.841962            1.605135                {'min_samples_split': 2, 'min_samples_leaf': 3}
# LogisticRegression-18            0.891304       1.255761             0.841530            1.642634  {'C': 0.9237666583949777, 'penalty': 'l2', 'solver': 'lbfgs'}
# SVC-22                           0.967391       1.128971             0.838798            1.437783                      {'C': 3.829710375376188, 'kernel': 'rbf'}

# %%
print("Most perplexed")
print(df.sort_values('Validation Perplex', ascending=False).head(5))
# Out:
# Most perplexed
#                Train Accuracy  Train Perplex  Validation Accuracy  Validation Perplex Params
# GaussianNB-16        0.750000       1.726729             0.715847            3.499490     {}
# GaussianNB-23        0.815217       1.743051             0.724044            3.118250     {}
# GaussianNB-2         0.891304       1.273440             0.743169            3.077893     {}
# GaussianNB-24        0.857143       1.420631             0.762943            2.913960     {}
# GaussianNB-9         0.813187       1.628914             0.746594            2.883137     {}

# %%
print("Least accurate")
print(df.sort_values('Validation Accuracy', ascending=True).head(5))
# Out:
# Least accurate
#                Train Accuracy  Train Perplex  Validation Accuracy  Validation Perplex Params
# GaussianNB-16        0.750000       1.726729             0.715847            3.499490     {}
# GaussianNB-23        0.815217       1.743051             0.724044            3.118250     {}
# GaussianNB-10        0.813187       1.438271             0.738420            2.514782     {}
# GaussianNB-2         0.891304       1.273440             0.743169            3.077893     {}
# GaussianNB-9         0.813187       1.628914             0.746594            2.883137     {}

# %%
#the whole summary
df
# Out:
#                            Train Accuracy  Train Perplex  Validation Accuracy  Validation Perplex                                                         Params
# RandomForestClassifier-1         1.000000       1.290677             0.819672            1.597563                {'min_samples_split': 2, 'min_samples_leaf': 3}
# RandomForestClassifier-2         1.000000       1.307658             0.808743            1.640384                {'min_samples_split': 2, 'min_samples_leaf': 3}
# RandomForestClassifier-3         0.978261       1.298210             0.800546            1.635822                {'min_samples_split': 2, 'min_samples_leaf': 3}
# RandomForestClassifier-4         1.000000       1.287171             0.762943            1.682191                {'min_samples_split': 2, 'min_samples_leaf': 3}
# RandomForestClassifier-5         0.989011       1.241060             0.803815            1.598521                {'min_samples_split': 2, 'min_samples_leaf': 3}
# RandomForestClassifier-6         0.967391       1.284013             0.789617            1.641959                {'min_samples_split': 2, 'min_samples_leaf': 3}
# RandomForestClassifier-7         0.989130       1.292796             0.811475            1.630574                {'min_samples_split': 2, 'min_samples_leaf': 3}
# RandomForestClassifier-8         0.978261       1.309477             0.814208            1.609299                {'min_samples_split': 2, 'min_samples_leaf': 3}
# RandomForestClassifier-9         0.989011       1.301071             0.782016            1.689949                {'min_samples_split': 2, 'min_samples_leaf': 3}
# RandomForestClassifier-10        0.989011       1.287731             0.771117            1.662235                {'min_samples_split': 2, 'min_samples_leaf': 3}
# RandomForestClassifier
# GaussianNB-13                    0.923913       1.339783             0.775956            1.697442                                                             {}
# GaussianNB-14                    0.857143       1.357317             0.801090            2.614432                                                             {}
# GaussianNB-15                    0.835165       1.340012             0.765668            2.268758                                                             {}
# GaussianNB-16                    0.750000       1.726729             0.715847            3.499490                                                             {}
# GaussianNB-17                    0.826087       1.373056             0.756831            2.076954                                                             {}
# GaussianNB-18                    0.815217       1.531830             0.781421            2.034239                                                             {}
# GaussianNB-19                    0.868132       1.357908             0.765668            2.419935                                                             {}
# GaussianNB-20                    0.890110       1.308790             0.790191            1.981407                                                             {}
# GaussianNB-21                    0.880435       1.351138             0.775956            2.171048                                                             {}
# GaussianNB-22                    0.782609       1.546266             0.765027            2.049516                                                             {}
# GaussianNB-23                    0.815217       1.743051             0.724044            3.118250                                                             {}
# GaussianNB-24                    0.857143       1.420631             0.762943            2.913960                                                             {}
# GaussianNB-25                    0.857143       1.404591             0.768392            2.158925                                                             {}
# SVC-1                            0.956522       1.259574             0.838798            1.455602                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-2                            0.934783       1.222347             0.827869            1.473527                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-3                            0.967391       1.190949             0.811475            1.523757                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-4                            0.978022       1.182399             0.828338            1.470524                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-5                            0.956044       1.169294             0.806540            1.519358                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-6                            0.989130       1.078167             0.836066            1.525045                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-7                            0.956522       1.275039             0.822404            1.481604                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-8                            0.945652       1.252069             0.800546            1.529681                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-9                            0.967033       1.177430             0.822888            1.542180                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-10                           0.945055       1.190777             0.801090            1.567862                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-11                           0.978261       1.090035             0.825137            1.493028                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-12                           0.902174       1.424877             0.838798            1.565289                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-13                           0.956522       1.144370             0.808743            1.549850                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-14                           0.978022       1.144144             0.820163            1.510413                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-15                           0.956044       1.217230             0.806540            1.518552                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-16                           0.956522       1.171679             0.808743            1.529316                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-17                           0.945652       1.185260             0.838798            1.443543                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-18                           0.978261       1.176890             0.838798            1.454002                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-19                           0.978022       1.184348             0.825613            1.503244                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-20                           0.934066       1.186106             0.825613            1.486090                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-21                           0.956522       1.257025             0.830601            1.467725                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-22                           0.967391       1.128971             0.838798            1.437783                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-23                           0.934783       1.280920             0.825137            1.492457                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-24                           0.978022       1.128927             0.795640            1.534495                      {'C': 3.829710375376188, 'kernel': 'rbf'}
# SVC-25                           0.956044       1.197122             0.850136            1.468701                      {'C': 3.829710375376188, 'kernel': 'rbf'}

# %%
#you can also investigate how the params of each model were chosen
##example performance of logistic regression hyperparameter tuning
#you can reuse this code to read the other models: just chose a different pickle file
#the parameters were tuning using crossfold validation also
lrp = pd.read_pickle('LogisticRegression-parameter_tuning.pickle')
lrp[['mean_test_score', 'std_test_score', 'rank_test_score', 'params']].sort_values('rank_test_score', ascending=True)
# Out:
#     mean_test_score  std_test_score  rank_test_score                                                              params
# 0          0.845043        0.053962                1       {'C': 0.9237666583949777, 'penalty': 'l2', 'solver': 'lbfgs'}
# 9          0.844935        0.053494                2       {'C': 0.5636157747519341, 'penalty': 'l2', 'solver': 'lbfgs'}
# 3          0.844826        0.053994                3       {'C': 0.7987417046727168, 'penalty': 'l2', 'solver': 'lbfgs'}
# 6          0.844826        0.053994                3       {'C': 0.6904364516090982, 'penalty': 'l2', 'solver': 'lbfgs'}
# 14         0.844826        0.054125                3        {'C': 1.087442906903663, 'penalty': 'l2', 'solver': 'lbfgs'}
# 8          0.844717        0.053922                6   {'C': 1.4097309261553663, 'penalty': 'l2', 'solver': 'newton-cg'}
# 11         0.844717        0.053922                6       {'C': 1.6870199211367845, 'penalty': 'l2', 'solver': 'lbfgs'}
# 19         0.844717        0.053966                8       {'C': 0.6516663720064764, 'penalty': 'l2', 'solver': 'lbfgs'}
# 1          0.844713        0.053085                9  {'C': 0.45802478587592566, 'penalty': 'l2', 'solver': 'newton-cg'}
# 16         0.844611        0.053844               10   {'C': 3.0803561250163276, 'penalty': 'l2', 'solver': 'newton-cg'}
# 15         0.844611        0.053844               10        {'C': 2.516454479648476, 'penalty': 'l2', 'solver': 'lbfgs'}
# 2          0.844611        0.053844               10   {'C': 3.2361382009613666, 'penalty': 'l2', 'solver': 'newton-cg'}
# 7          0.844611        0.053844               10        {'C': 3.766539408293475, 'penalty': 'l2', 'solver': 'lbfgs'}
# 5          0.844611        0.053844               10        {'C': 3.646472822013713, 'penalty': 'l2', 'solver': 'lbfgs'}
# 4          0.844611        0.053844               10   {'C': 2.8625422022310496, 'penalty': 'l2', 'solver': 'newton-cg'}
# 18         0.844611        0.053844               10        {'C': 2.943741567749782, 'penalty': 'l2', 'solver': 'lbfgs'}
# 10         0.844611        0.053844               10       {'C': 3.4386621906659007, 'penalty': 'l2', 'solver': 'lbfgs'}
# 12         0.844609        0.053894               18   {'C': 1.9228562259374238, 'penalty': 'l2', 'solver': 'newton-cg'}
# 17         0.844500        0.053777               19         {'C': 2.07455476266405, 'penalty': 'l2', 'solver': 'lbfgs'}
# 13         0.844300        0.050822               20   {'C': 0.0697221820081837, 'penalty': 'l2', 'solver': 'newton-cg'}

# %%
svcp = pd.read_pickle('SVC-parameter_tuning.pickle')
svcp[['mean_test_score', 'std_test_score', 'rank_test_score', 'params']].sort_values('rank_test_score', ascending=True)
# Out:
#     mean_test_score  std_test_score  rank_test_score                                          params
# 18         0.857007        0.049202                1       {'C': 3.829710375376188, 'kernel': 'rbf'}
# 15         0.853700        0.047096                2      {'C': 1.3400783293272838, 'kernel': 'rbf'}
# 17         0.850771        0.047424                3      {'C': 0.9301317895411385, 'kernel': 'rbf'}
# 13         0.848360        0.049411                4      {'C': 0.7249131567350804, 'kernel': 'rbf'}
# 16         0.843899        0.047774                5      {'C': 3.168085572717698, 'kernel': 'poly'}
# 10         0.843896        0.048121                6      {'C': 2.881014573887268, 'kernel': 'poly'}
# 8          0.843795        0.048466                7      {'C': 3.265651819034257, 'kernel': 'poly'}
# 2          0.842490        0.046598                8     {'C': 1.9830105146414194, 'kernel': 'poly'}
# 9          0.841816        0.051802                9     {'C': 0.31778272119557993, 'kernel': 'rbf'}
# 4          0.841302        0.046506               10     {'C': 1.8268856482973406, 'kernel': 'poly'}
# 5          0.837374        0.047142               11     {'C': 1.2321450997129393, 'kernel': 'poly'}
# 1          0.834952        0.046465               12     {'C': 0.9309605895633108, 'kernel': 'poly'}
# 0          0.832341        0.045744               13      {'C': 0.671288376491697, 'kernel': 'poly'}
# 14         0.831121        0.057064               14     {'C': 0.12427203526525021, 'kernel': 'rbf'}
# 6          0.829490        0.047577               15      {'C': 0.601400503676921, 'kernel': 'poly'}
# 19         0.759790        0.063424               16  {'C': 0.7618672939914006, 'kernel': 'sigmoid'}
# 3          0.750850        0.066529               17  {'C': 1.3250049879679842, 'kernel': 'sigmoid'}
# 7          0.747464        0.063828               18   {'C': 2.437570865518892, 'kernel': 'sigmoid'}
# 11         0.747116        0.065316               19  {'C': 2.2376590404741474, 'kernel': 'sigmoid'}
# 12         0.746461        0.065448               20  {'C': 2.9987446307812085, 'kernel': 'sigmoid'}

# %%
rfp = pd.read_pickle('RandomForestClassifier-parameter_tuning.pickle')
rfp[['mean_test_score', 'std_test_score', 'rank_test_score', 'params']].sort_values('rank_test_score', ascending=True)
# Out:
#     mean_test_score  std_test_score  rank_test_score                                           params
# 0          0.856703        0.050004                1  {'min_samples_split': 2, 'min_samples_leaf': 3}
# 3          0.855928        0.048121                2  {'min_samples_split': 4, 'min_samples_leaf': 4}
# 2          0.855473        0.048678                3  {'min_samples_split': 5, 'min_samples_leaf': 2}
# 6          0.855377        0.049745                4  {'min_samples_split': 4, 'min_samples_leaf': 2}
# 18         0.855058        0.051527                5  {'min_samples_split': 4, 'min_samples_leaf': 5}
# 12         0.854915        0.048026                6  {'min_samples_split': 3, 'min_samples_leaf': 2}
# 9          0.854742        0.048248                7  {'min_samples_split': 6, 'min_samples_leaf': 4}
# 14         0.854729        0.047125                8  {'min_samples_split': 2, 'min_samples_leaf': 5}
# 10         0.854715        0.049206                9  {'min_samples_split': 2, 'min_samples_leaf': 1}
# 13         0.854522        0.051648               10  {'min_samples_split': 4, 'min_samples_leaf': 6}
# 8          0.854389        0.048975               11  {'min_samples_split': 4, 'min_samples_leaf': 3}
# 19         0.853848        0.050947               12  {'min_samples_split': 5, 'min_samples_leaf': 5}
# 5          0.853312        0.051822               13  {'min_samples_split': 2, 'min_samples_leaf': 2}
# 17         0.853309        0.050140               14  {'min_samples_split': 3, 'min_samples_leaf': 3}
# 16         0.853203        0.049958               15  {'min_samples_split': 5, 'min_samples_leaf': 6}
# 4          0.852983        0.048959               16  {'min_samples_split': 6, 'min_samples_leaf': 6}
# 15         0.852638        0.052792               17  {'min_samples_split': 6, 'min_samples_leaf': 2}
# 7          0.852541        0.050405               18  {'min_samples_split': 3, 'min_samples_leaf': 1}
# 11         0.852536        0.048464               19  {'min_samples_split': 5, 'min_samples_leaf': 1}
# 1          0.849242        0.048694               20  {'min_samples_split': 4, 'min_samples_leaf': 1}
